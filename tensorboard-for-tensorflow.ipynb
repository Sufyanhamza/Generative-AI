# %% [markdown]
# # **`Tensorboard for Tensorflow`**
#
# ## **`Note:`** Please upvote the [notebook on Kaggle](https://www.kaggle.com/code/muhammadaammartufail/tensorboard-for-tensorflow)
#
# This tutorial will show you step by step guide on how to use Tensorboard for Tensorflow. Tensorboard is a visualization tool provided by Tensorflow to visualize the training process of your model. It is very helpful to visualize the training process, model architecture, and other important details of your model.
#
# ## **`What is Tensorboard?`**
#
# TensorBoard is a suite of visualization tools that makes it easier to understand, debug, and optimize TensorFlow programs. It includes a suite of tools for visualizing data flow graphs, profiling, and debugging TensorFlow programs.
#
# ## **`Why Tensorboard?`**
#
# TensorBoard provides the visualization and tooling needed for machine learning experimentation:
#
# - Tracking and visualizing metrics such as loss and accuracy
# - Visualizing the model graph (ops and layers)
# - Viewing histograms of weights, biases, or other tensors as they change over time
# - Projecting embeddings to a lower-dimensional space
# - Displaying images, text, and audio data
# - Profiling input data and model structure
# - Displaying profiled data, such as input pipeline processing time, model execution time, and how long each op takes
#
# ## **`How to use Tensorboard?`**
#
# To use Tensorboard, you need to install Tensorflow and then you can use Tensorboard to visualize the training process of your model. Here is a step by step guide on how to use Tensorboard.
#
# to install Tensorflow and tensorboard, you can use the following command.
#
# ```python
# !pip install tensorflow
# !pip intall tensorboard
# ```
#
# <h1 style="font-family: 'poppins'; font-weight: bold; color: Green;">👨‍💻Author: Dr. Muhammad Aamamr Tufail</h1>
#
# [![GitHub](https://img.shields.io/badge/GitHub-Profile-blue?style=for-the-badge&logo=github)](https://github.com/AammarTufail)
# [![Kaggle](https://img.shields.io/badge/Kaggle-Profile-blue?style=for-the-badge&logo=kaggle)](https://www.kaggle.com/muhammadaammartufail)
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-Profile-blue?style=for-the-badge&logo=linkedin)](https://www.linkedin.com/in/dr-muhammad-aammar-tufail-02471213b/)
#
# [![YouTube](https://img.shields.io/badge/YouTube-Profile-red?style=for-the-badge&logo=youtube)](https://www.youtube.com/@codanics)
# [![Facebook](https://img.shields.io/badge/Facebook-Profile-blue?style=for-the-badge&logo=facebook)](https://www.facebook.com/aammar.tufail)
# [![TikTok](https://img.shields.io/badge/TikTok-Profile-black?style=for-the-badge&logo=tiktok)](https://www.tiktok.com/@draammar)
#
# [![Twitter/X](https://img.shields.io/badge/Twitter-Profile-blue?style=for-the-badge&logo=twitter)](https://twitter.com/aammar_tufail)
# [![Instagram](https://img.shields.io/badge/Instagram-Profile-blue?style=for-the-badge&logo=instagram)](https://www.instagram.com/aammartufail/)
# [![Email](https://img.shields.io/badge/Email-Contact%20Me-red?style=for-the-badge&logo=email)](mailto:aammar@codanics.com)

# %% [markdown]
# Using TensorBoard for visualizing the training process of a simple neural network for basic rectangular data involves several steps. Below, I'll outline a basic example using TensorFlow and Keras to train a neural network on some rectangular data and visualize the training process using TensorBoard:
#
# 1. **Import necessary libraries**:

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import TensorBoard
# ignore warnings
import warnings
warnings.filterwarnings('ignore')
# ignore warnings in the output
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
# Out:
# WARNING:tensorflow:From C:\Users\Sufiyan Hamza\AppData\Local\Temp\ipykernel_16660\3038728259.py:10: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.

# %% [markdown]
# 2. **Prepare your data**:
#
# For this example, let's assume you have some rectangular data stored in numpy arrays `X_train` and `y_train`.

# %%
# Load the MNIST dataset
mnist = tf.keras.datasets.mnist

# Split the dataset into training and testing sets
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Normalize the pixel values to be between 0 and 1
X_train = X_train / 255.0
X_test = X_test / 255.0

# plot the first 9 images in the training set
import matplotlib.pyplot as plt
for i in range(9):
    plt.subplot(330 + 1 + i)
    plt.imshow(X_train[i], cmap=plt.get_cmap('gray'))
plt.show()

# %% [markdown]
# 3. **Define your neural network model**:

# %%
# create the model using convolutional layers, max pooling layers, and a dropout layer
model = Sequential([
    tf.keras.layers.Conv2D(10, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    tf.keras.layers.MaxPooling2D((2,2)),
    tf.keras.layers.Conv2D(10, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2,2)),

    tf.keras.layers.Conv2D(10, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(10, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((1,1)),  # modify the pool size to match the output shape
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.2),  # add dropout layer with a dropout rate of 0.2
    tf.keras.layers.Dense(10, activation='softmax')
])

# %% [markdown]
# 4. **Compile your model**:

# %%
# compile the model 
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# train the model
history = model.fit(X_train, y_train, epochs=5, validation_data=(X_test, y_test))

# evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)

# plot the training and validation accuracy and loss at each epoch
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 54s 22ms/step - accuracy: 0.5035 - loss: 1.3781 - val_accuracy: 0.9158 - val_loss: 0.3175
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 71s 21ms/step - accuracy: 0.7661 - loss: 0.6557 - val_accuracy: 0.9522 - val_loss: 0.2519
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 40s 21ms/step - accuracy: 0.8110 - loss: 0.5654 - val_accuracy: 0.9590 - val_loss: 0.1865
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 42s 21ms/step - accuracy: 0.8375 - loss: 0.5023 - val_accuracy: 0.9660 - val_loss: 0.1584
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 49s 26ms/step - accuracy: 0.8503 - loss: 0.4695 - val_accuracy: 0.9704 - val_loss: 0.1416
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9645 - loss: 0.1631
# Test accuracy: 0.9703999757766724

# %% [markdown]
# `Lets's do it with tensorboard`

# %%
# create the model using convolutional layers, max pooling layers, and a dropout layer
model = Sequential([
    tf.keras.layers.Conv2D(10, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    tf.keras.layers.MaxPooling2D((2,2)),
    tf.keras.layers.Conv2D(10, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2,2)),

    tf.keras.layers.Conv2D(10, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(10, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((1,1)),  # modify the pool size to match the output shape
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.2),  # add dropout layer with a dropout rate of 0.2
    tf.keras.layers.Dense(10, activation='softmax')
])
# compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# 5. **Set up TensorBoard callback**:

# %%
# Clear any logs from previous runs
# !rm -rf ./logs/
# Out:
# 'rm' is not recognized as an internal or external command,
# operable program or batch file.

# %%
tensorboard_callback = TensorBoard(log_dir='./logs/adam', histogram_freq=1)

# %% [markdown]
# 6. **Train your model**:

# %%
model.fit(X_train, y_train, epochs=5, batch_size=32, validation_data=(X_test,y_test), callbacks=[tensorboard_callback])
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - accuracy: 0.6289 - loss: 1.0919 - val_accuracy: 0.9397 - val_loss: 0.2126
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 40s 22ms/step - accuracy: 0.8580 - loss: 0.4412 - val_accuracy: 0.9521 - val_loss: 0.1624
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 41s 22ms/step - accuracy: 0.8823 - loss: 0.3682 - val_accuracy: 0.9641 - val_loss: 0.1264
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 82s 22ms/step - accuracy: 0.9000 - loss: 0.3156 - val_accuracy: 0.9691 - val_loss: 0.1104
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 43s 23ms/step - accuracy: 0.9097 - loss: 0.2885 - val_accuracy: 0.9734 - val_loss: 0.0934

# %% [markdown]
# 7. **Run TensorBoard**:
#
# Open a terminal and navigate to your working directory. Then run:

# %%
# Activate inline tensorboard extension
# %load_ext tensorboard

# %%
# run tensorboad in the notebook try using with and without %sign
# %tensorboard --logdir=./logs
# Out:
# Reusing TensorBoard on port 6007 (pid 13728), started 0:01:01 ago. (Use '!kill 13728' to kill it.)
#       <iframe id="tensorboard-frame-f64c5f963bea7630" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-f64c5f963bea7630");
#           const url = new URL("http://localhost");
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# 8. **Visualize training progress**:
#
# Once TensorBoard is running, you can navigate to the Scalars tab to visualize metrics like loss and accuracy over training epochs. You can also explore other tabs like Graphs, Histograms, and Distributions to gain insights into your model's structure and behavior.
#
# That's it! This is a basic example of how to use TensorBoard to visualize the training process of a simple neural network for rectangular data. You can further customize the TensorBoard callback to log additional information or use more advanced features as needed.

# %% [markdown]
# 9. **Hyper parameter Tuning and visualization**:

# %%
# create the model using convolutional layers, max pooling layers, and a dropout layer
model = Sequential([
    tf.keras.layers.Conv2D(10, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    tf.keras.layers.MaxPooling2D((2,2)),
    tf.keras.layers.Conv2D(10, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2,2)),

    tf.keras.layers.Conv2D(10, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(10, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((1,1)),  # modify the pool size to match the output shape
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.2),  # add dropout layer with a dropout rate of 0.2
    tf.keras.layers.Dense(10, activation='softmax')
])
# compile the model with SGD optimizer
model.compile(optimizer='SGD',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

tensorboard_callback = TensorBoard(log_dir='./logs/SGD', histogram_freq=1)
model.fit(X_train, y_train, epochs=5, batch_size=32, validation_data=(X_test,y_test), callbacks=[tensorboard_callback])
# %tensorboard --logdir=./logs
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 52s 27ms/step - accuracy: 0.2784 - loss: 1.9870 - val_accuracy: 0.8706 - val_loss: 0.5176
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 81s 26ms/step - accuracy: 0.7448 - loss: 0.7265 - val_accuracy: 0.9160 - val_loss: 0.3031
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 58s 31ms/step - accuracy: 0.8062 - loss: 0.5504 - val_accuracy: 0.9389 - val_loss: 0.2201
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 61s 20ms/step - accuracy: 0.8411 - loss: 0.4647 - val_accuracy: 0.9465 - val_loss: 0.1782
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 33s 17ms/step - accuracy: 0.8518 - loss: 0.4149 - val_accuracy: 0.9562 - val_loss: 0.1464
# Reusing TensorBoard on port 6007 (pid 13728), started 0:34:06 ago. (Use '!kill 13728' to kill it.)
#       <iframe id="tensorboard-frame-129b7ba44870294e" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-129b7ba44870294e");
#           const url = new URL("http://localhost");
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# # Hyper-Paramter Tuning and Visualization using Tensorboard

# %%
# Define different optimizers
optimizers = ['SGD', 'Adam']
# optimizer = ['SGD', 'Adam', 'RMSprop', 'Adagrad', 'Adadelta', 'Adamax', 'Nadam']

# Train the model with different optimizers and store each optimizer in a different callback function
for optimizer in optimizers:
    model = Sequential([
        tf.keras.layers.Conv2D(10, (3, 3), activation='relu', input_shape=(28, 28, 1)),
        tf.keras.layers.MaxPooling2D((2,2)),
        tf.keras.layers.Conv2D(10, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2,2)),
        tf.keras.layers.Conv2D(10, (3, 3), activation='relu'),
        tf.keras.layers.Conv2D(10, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((1,1)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    
    model.compile(optimizer=optimizer,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    
    # Define different batch sizes
    batch_sizes = [16, 32, 64, 128]
    
    # Train the model with different batch sizes and store each batch size in a different callback function
    for batch_size in batch_sizes:
        log_dir = f'./logs/{optimizer}_batch_size_{batch_size}'
        tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
        model.fit(X_train, y_train, epochs=5, batch_size=batch_size, validation_data=(X_test,y_test), 
                  callbacks=[tensorboard_callback])

# Load the TensorBoard notebook extension
# %load_ext tensorboard

# Run TensorBoard
# %tensorboard --logdir=./logs
# Out:
# Epoch 1/5
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 60s 16ms/step - accuracy: 0.4212 - loss: 1.6274 - val_accuracy: 0.9381 - val_loss: 0.2213
# Epoch 2/5
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 83s 16ms/step - accuracy: 0.8454 - loss: 0.4542 - val_accuracy: 0.9530 - val_loss: 0.1651
# Epoch 3/5
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 53s 14ms/step - accuracy: 0.8773 - loss: 0.3592 - val_accuracy: 0.9637 - val_loss: 0.1120
# Epoch 4/5
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 74s 20ms/step - accuracy: 0.8942 - loss: 0.3128 - val_accuracy: 0.9609 - val_loss: 0.1210
# Epoch 5/5
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 94s 23ms/step - accuracy: 0.9067 - loss: 0.2754 - val_accuracy: 0.9722 - val_loss: 0.0896
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 77s 41ms/step - accuracy: 0.9120 - loss: 0.2574 - val_accuracy: 0.9755 - val_loss: 0.0797
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 62s 30ms/step - accuracy: 0.9158 - loss: 0.2478 - val_accuracy: 0.9760 - val_loss: 0.0786
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 43s 23ms/step - accuracy: 0.9169 - loss: 0.2449 - val_accuracy: 0.9744 - val_loss: 0.0782
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 33s 17ms/step - accuracy: 0.9196 - loss: 0.2393 - val_accuracy: 0.9775 - val_loss: 0.0716
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 32s 17ms/step - accuracy: 0.9228 - loss: 0.2276 - val_accuracy: 0.9763 - val_loss: 0.0722
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 27s 28ms/step - accuracy: 0.9273 - loss: 0.2172 - val_accuracy: 0.9791 - val_loss: 0.0649
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 26s 28ms/step - accuracy: 0.9287 - loss: 0.2134 - val_accuracy: 0.9788 - val_loss: 0.0659
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 28s 30ms/step - accuracy: 0.9260 - loss: 0.2189 - val_accuracy: 0.9782 - val_loss: 0.0668
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 25s 27ms/step - accuracy: 0.9293 - loss: 0.2114 - val_accuracy: 0.9786 - val_loss: 0.0660
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 26s 28ms/step - accuracy: 0.9313 - loss: 0.2070 - val_accuracy: 0.9792 - val_loss: 0.0657
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.9316 - loss: 0.2081 - val_accuracy: 0.9801 - val_loss: 0.0624
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 25s 53ms/step - accuracy: 0.9299 - loss: 0.2095 - val_accuracy: 0.9795 - val_loss: 0.0613
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 23s 48ms/step - accuracy: 0.9345 - loss: 0.2010 - val_accuracy: 0.9801 - val_loss: 0.0605
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.9321 - loss: 0.2027 - val_accuracy: 0.9800 - val_loss: 0.0604
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 32s 68ms/step - accuracy: 0.9362 - loss: 0.1959 - val_accuracy: 0.9788 - val_loss: 0.0633
# Epoch 1/5
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 77s 20ms/step - accuracy: 0.6124 - loss: 1.0894 - val_accuracy: 0.9530 - val_loss: 0.1839
# Epoch 2/5
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 75s 20ms/step - accuracy: 0.8533 - loss: 0.4416 - val_accuracy: 0.9664 - val_loss: 0.1243
# Epoch 3/5
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 82s 20ms/step - accuracy: 0.8923 - loss: 0.3525 - val_accuracy: 0.9717 - val_loss: 0.1089
# Epoch 4/5
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 84s 20ms/step - accuracy: 0.8994 - loss: 0.3182 - val_accuracy: 0.9728 - val_loss: 0.1050
# Epoch 5/5
# 3750/3750 ━━━━━━━━━━━━━━━━━━━━ 63s 17ms/step - accuracy: 0.9059 - loss: 0.2973 - val_accuracy: 0.9743 - val_loss: 0.0972
# Epoch 1/5
#  289/1875 ━━━━━━━━━━━━━━━━━━━━ 47s 30ms/step - accuracy: 0.9124 - loss: 0.2831
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 31
#      29         log_dir = f'./logs/{optimizer}_batch_size_{batch_size}'
#      30         tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
# ---> 31         model.fit(X_train, y_train, epochs=5, batch_size=batch_size, validation_data=(X_test,y_test),
#      32                   callbacks=[tensorboard_callback])
#      34 # Load the TensorBoard notebook extension
#      35 get_ipython().run_line_magic('load_ext', 'tensorboard')
#
# File c:\Users\Sufiyan Hamza\anaconda3\envs\deep_practice\lib\site-packages\keras\src\utils\traceback_utils.py:118, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     116 filtered_tb = None
#     117 try:
# --> 118     return fn(*args, **kwargs)
#     119 except Exception as e:
#     120     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Sufiyan Hamza\anaconda3\envs\deep_practice\lib\site-packages\keras\src\backend\tensorflow\trainer.py:324, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     322 callbacks.on_train_batch_begin(step)
#     323 logs = self.train_function(iterator)
# --> 324 callbacks.on_train_batch_end(
#     325     step, self._pythonify_logs(logs)
#     326 )
#     327 if self.stop_training:
#     328     break
#
# File c:\Users\Sufiyan Hamza\anaconda3\envs\deep_practice\lib\site-packages\keras\src\callbacks\callback_list.py:107, in CallbackList.on_train_batch_end(self, batch, logs)
#     105 logs = logs or {}
#     106 for callback in self.callbacks:
# --> 107     callback.on_train_batch_end(batch, logs=logs)
#
# File c:\Users\Sufiyan Hamza\anaconda3\envs\deep_practice\lib\site-packages\keras\src\callbacks\progbar_logger.py:58, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#      57 def on_train_batch_end(self, batch, logs=None):
# ---> 58     self._update_progbar(batch, logs)
#
# File c:\Users\Sufiyan Hamza\anaconda3\envs\deep_practice\lib\site-packages\keras\src\callbacks\progbar_logger.py:95, in ProgbarLogger._update_progbar(self, batch, logs)
#      92 self.seen = batch + 1  # One-indexed.
#      94 if self.verbose == 1:
# ---> 95     self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File c:\Users\Sufiyan Hamza\anaconda3\envs\deep_practice\lib\site-packages\keras\src\utils\progbar.py:182, in Progbar.update(self, current, values, finalize)
#     179 if finalize:
#     180     message += "\n"
# --> 182 io_utils.print_msg(message, line_break=False)
#     183 self._prev_total_width = total_width
#     184 message = ""
#
# File c:\Users\Sufiyan Hamza\anaconda3\envs\deep_practice\lib\site-packages\keras\src\utils\io_utils.py:99, in print_msg(message, line_break)
#      97     else:
#      98         sys.stdout.write(message)
# ---> 99     sys.stdout.flush()
#     100 else:
#     101     logging.info(message)
#
# File c:\Users\Sufiyan Hamza\anaconda3\envs\deep_practice\lib\site-packages\ipykernel\iostream.py:609, in OutStream.flush(self)
#     607     self.pub_thread.schedule(evt.set)
#     608     # and give a timeout to avoid
# --> 609     if not evt.wait(self.flush_timeout):
#     610         # write directly to __stderr__ instead of warning because
#     611         # if this is happening sys.stderr may be the problem.
#     612         print("IOStream.flush timed out", file=sys.__stderr__)
#     613 else:
#
# File c:\Users\Sufiyan Hamza\anaconda3\envs\deep_practice\lib\threading.py:581, in Event.wait(self, timeout)
#     579 signaled = self._flag
#     580 if not signaled:
# --> 581     signaled = self._cond.wait(timeout)
#     582 return signaled
#
# File c:\Users\Sufiyan Hamza\anaconda3\envs\deep_practice\lib\threading.py:316, in Condition.wait(self, timeout)
#     314 else:
#     315     if timeout > 0:
# --> 316         gotit = waiter.acquire(True, timeout)
#     317     else:
#     318         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
# Run TensorBoard
# %tensorboard --logdir=./logs
# Out:
# Reusing TensorBoard on port 6007 (pid 60114), started 0:06:08 ago. (Use '!kill 60114' to kill it.)
#       <iframe id="tensorboard-frame-72be5da33960dac6" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-72be5da33960dac6");
#           const url = new URL("http://localhost");
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# # **`Run Hyperparameter tuning and save the best model using TensorBoard.`**

# %%
# %%time
from tensorflow.keras.callbacks import ModelCheckpoint
# Import the ModelCheckpoint callback
# Define different optimizers
optimizers = ['SGD', 'Adam']
# optimizers = ['SGD', 'Adam', 'RMSprop', 'Adadelta', 'Adagrad', 'Adamax', 'Nadam', 'Ftrl']

# Train the model with different optimizers and store each optimizer in a different callback function
for optimizer in optimizers:
    model = Sequential([
        tf.keras.layers.Conv2D(10, (3, 3), activation='relu', input_shape=(28, 28, 1)),
        tf.keras.layers.MaxPooling2D((2,2)),
        tf.keras.layers.Conv2D(10, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2,2)),
        tf.keras.layers.Conv2D(10, (3, 3), activation='relu'),
        tf.keras.layers.Conv2D(10, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((1,1)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    
    model.compile(optimizer=optimizer,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    
    # Define different batch sizes
    batch_sizes = [16, 32, 64, 128]
    
    # Train the model with different batch sizes and store each batch size in a different callback function
    for batch_size in batch_sizes:
        log_dir = f'./logs/{optimizer}_batch_size_{batch_size}'
        
        # Define the ModelCheckpoint callback to save the best model based on validation accuracy
        checkpoint_callback = ModelCheckpoint(filepath=f'./models/best_model_{optimizer}_batch_size_{batch_size}.h5',
                                              monitor='val_accuracy',
                                              save_best_only=True,
                                              mode='max',
                                              verbose=1)
        
        tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
        
        # Train the model with the callbacks
        model.fit(X_train, y_train, epochs=5, batch_size=batch_size, validation_data=(X_test,y_test), callbacks=[tensorboard_callback, checkpoint_callback])

# Load the TensorBoard notebook extension
# %load_ext tensorboard

# Run TensorBoard
# %tensorboard --logdir=./logs

# %%
# %tensorboard --logdir=./logs
# Out:
# Reusing TensorBoard on port 6007 (pid 60114), started 0:09:45 ago. (Use '!kill 60114' to kill it.)
#       <iframe id="tensorboard-frame-6a61f7bc098c372e" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-6a61f7bc098c372e");
#           const url = new URL("http://localhost");
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# <h1 style="font-family: 'poppins'; font-weight: bold; color: Green;">👨‍💻Author: Dr. Muhammad Aamamr Tufail</h1>
#
# [![GitHub](https://img.shields.io/badge/GitHub-Profile-blue?style=for-the-badge&logo=github)](https://github.com/AammarTufail)
# [![Kaggle](https://img.shields.io/badge/Kaggle-Profile-blue?style=for-the-badge&logo=kaggle)](https://www.kaggle.com/muhammadaammartufail)
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-Profile-blue?style=for-the-badge&logo=linkedin)](https://www.linkedin.com/in/dr-muhammad-aammar-tufail-02471213b/)
#
# [![YouTube](https://img.shields.io/badge/YouTube-Profile-red?style=for-the-badge&logo=youtube)](https://www.youtube.com/@codanics)
# [![Facebook](https://img.shields.io/badge/Facebook-Profile-blue?style=for-the-badge&logo=facebook)](https://www.facebook.com/aammar.tufail)
# [![TikTok](https://img.shields.io/badge/TikTok-Profile-black?style=for-the-badge&logo=tiktok)](https://www.tiktok.com/@draammar)
#
# [![Twitter/X](https://img.shields.io/badge/Twitter-Profile-blue?style=for-the-badge&logo=twitter)](https://twitter.com/aammar_tufail)
# [![Instagram](https://img.shields.io/badge/Instagram-Profile-blue?style=for-the-badge&logo=instagram)](https://www.instagram.com/aammartufail/)
# [![Email](https://img.shields.io/badge/Email-Contact%20Me-red?style=for-the-badge&logo=email)](mailto:aammar@codanics.com)
#
# ---
